# %%
# !pip install --upgrade streamlit
# !pip install streamlit-option-menu
# !pip install pyngrok
# !pip install nltk
# !pip install wordcloud

import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# %%
from pyngrok import ngrok
# !ngrok config add-authtoken 2OQr3VN0TkWlEyAlKPB64KMsgH1_itXF5MuXsTKsWa8iDgDy
ngrok.set_auth_token("2h26Q9YtUwgU9ZKzt7wCAA9yfRG_4skowWokFo8GLnjpJ1UBA")
url = ngrok.connect()
print(url)
# !streamlit run --server.port 80 drive/MyDrive/AdFactors_PR_Assignment/AdFactors_PR_app.py
# Out:
# NgrokTunnel: "https://eb52-34-148-122-39.ngrok-free.app" -> "http://localhost:80"
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:80
#   Network URL: http://172.28.0.12:80
#   External URL: http://34.148.122.39:80
#
# 2024-05-27 19:51:09.209 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-05-27 19:51:31.733 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-05-27 19:51:36.443 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# ...

# %%
ngrok.kill()
